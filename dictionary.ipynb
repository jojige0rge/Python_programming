# %%
dict1 = {"anjali" : 23 ,"vibin" : 19 ,"arjun" : 26}
dict1
# Out:
# {'anjali': 23, 'vibin': 19, 'arjun': 26}

# %%
dict1.keys()
# Out:
# dict_keys(['anjali', 'vibin', 'arjun'])

# %%
my_dict = {"id" :123 ,"name" : "python" ,"age" :34}
print(my_dict)
# Out:
# {'id': 123, 'name': 'python', 'age': 34}

# %%
my_dict = {'name' : 'abc' , 'age' : 56 , 'id' :23}
print(my_dict)
# Out:
# {'name': 'abc', 'age': 56, 'id': 23}

# %%
my_dict['name' : 'joji']
print(my_dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-e74d34cc6667> in <cell line: 1>()
# ----> 1 my_dict['name' : 'joji']
#       2 print(my_dict)
#
# TypeError: unhashable type: 'slice'

# %%
dict2 = {"sub1": 87, "sub2": 89, "sub3": 90}
print(dict2)
# Out:
# {'sub1': 87, 'sub2': 89, 'sub3': 90}

# %%
dict2.keys()
# Out:
# dict_keys(['sub1', 'sub2', 'sub3'])

# %%
dict2.values()
# Out:
# dict_values([87, 89, 90])

# %%
print(dict2.items())
# Out:
# dict_items([('sub1', 87), ('sub2', 89), ('sub3', 90)])

# %%
dict2["sub1"]
# Out:
# 87

# %%
print(dict2["sub1"])
# Out:
# 87
