# %%
my_set = {1,2,3}
print(my_set)
my_set = {1.0 ,"Hello" ,(1,2,3)}
print(my_set)
# Out:
# {1, 2, 3}
# {1.0, (1, 2, 3), 'Hello'}

# %%
set1 = {1,1,1,2,3,4,5}
print(set1)
# Out:
# {1, 2, 3, 4, 5}

# %%
set()
# Out:
# set()

# %%
set2 = {}
print(set2)
# Out:
# {}
