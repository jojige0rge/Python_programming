# %%
x = [11 ,"joji" ,1.314 ,"hello"]
print(x)
# Out:
# [11, 'joji', 1.314, 'hello']

# %%
type(x)
# Out:
# list

# %%
len(x)
# Out:
# 4

# %%
print(x[1])
# Out:
# joji

# %%
print(x[0:3])
# Out:
# [11, 'joji', 1.314]

# %%
#empty list
list = []

# %%
list1 = [200 ,300 ,"anjali" ,"anu" ,34555 ,"adhi" ,"vioin" ,347]

# %%
list3 = ["python" ,"java" ,"c#" ,"android" ,"ios"]
print(list3)
# Out:
# ['python', 'java', 'c#', 'android', 'ios']

# %%
list3 = ["python" ,"java" ,"c#" ,"android" ,"ios"]
list3[2] = "dot net"
print(list3)
# Out:
# ['python', 'java', 'dot net', 'android', 'ios']

# %%
#concantination operator
list = ["python" ,123]
print(list + list)
# Out:
# ['python', 123, 'python', 123]

# %%
str1 = "hello how are you"
x = list(str1)
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-120044de1ffd> in <cell line: 2>()
#       1 str1 = "hello how are you"
# ----> 2 x = my_list(str1)
#       3 print(x)
#
# TypeError: 'list' object is not callable

# %%
x.reverse()
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-11e7a658f56e> in <cell line: 1>()
# ----> 1 x.reverse()
#       2 print(x)
#
# NameError: name 'x' is not defined

# %%
#tuple
