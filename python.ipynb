# %%
x = 10
print(x)
# Out:
# 10

# %%
a = int(input('enter first number:'))
b = int(input('enter second number:'))
c = a * b
print(c)
# Out:
# enter first number:4
# enter second number:9
# 36

# %%
x = 5.6
x
# Out:
# 5.6

# %%
z = "joji"
z
# Out:
# 'joji'

# %%
p ,q ,r = 10 ,23 ,34
print(p)
print(q)
print(r)
# Out:
# 10
# 23
# 34

# %%
a = 60
b = 10
c = a//b
c
# Out:
# 6

# %%
#assignment operator
j = 15
j += 12
j
# Out:
# 27

# %%
h = 5
h *= 4
h
# Out:
# 20

# %%
k = 20
k //= 5
k
# Out:
# 4

# %%
#comparison operator
var1 = 12
var2 = 12
var1 == var2
# Out:
# True

# %%
var1 = 12
var2 = 10
var1 == var2
# Out:
# False

# %%
var1 = 56
var2 = 67
var2 < var1
# Out:
# False

# %%
var1 = 56
var2 = 67
var1 <= var2
# Out:
# True

# %%
var1 = 56
var2 = 56
var1 <= var2
# Out:
# True

# %%
#logical operator
#and
x = 5
print(x > 3 and x < 4)
# Out:
# False

# %%
#OR
x = 5
print(x > 3 or x < 4)
# Out:
# True

# %%
y = 20
print(y > 10 and y < 25)
# Out:
# True

# %%
#not
x = 5
print(not(x > 3 and x < 10))
# Out:
# False

# %%
#identity operator
#is
x = ["apple","banana"]
y = ["apple","banana"]
z = x
print(x is z)
# Out:
# True

# %%
print(x is y)
# Out:
# False

# %%
#is not
x = ["apple", "banana"]
y = ["apple", "banana"]
z = x
print(x is not z)
# Out:
# False

# %%
print(x == y)
# Out:
# True

# %%
print(x != y)
# Out:
# False

# %%
#membership operator
#in
x = ["apple","banana"]
print("banana" in x)
# Out:
# True

# %%
print("pineapple" in x)
# Out:
# False

# %%
#not in
x = ["apple","banana"]
print("pineapple" not in x)
# Out:
# True

# %%
y = ["tomato","carrot","chilly","potato"]
print("chilly"not in y)
# Out:
# False

# %%
#Numbers
x = 1 #int
y = 2.8 #float
z = 1j #complex

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
p = -3255522
type(p)
# Out:
# int

# %%
#type conversion
a = 10
b = float(a)
b
# Out:
# 10.0

# %%
q = 345.67
r = int(q)
r
# Out:
# 345

# %%
q = 345.67
r = complex(q)
r
# Out:
# (345.67+0j)

# %% [markdown]
# #types of datatypes
# 1.boolean
# -true or false
# 2.numeric
# -int
# -double
# -float
# -complex
# 3.SequenceTypes
# -str
# -bytes
# -byte array
# -list
# -tuple
# 4.sets
# -set
# -frozen set
# 5.mapping
# -dict
