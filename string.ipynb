# %% [markdown]
# Strings

# %%
myname = "joji george"
myname
# Out:
# 'joji george'

# %%
type(myname)
# Out:
# str

# %%
#indexing []
#positive indexing start from 0
#space also counts
myname[3]
# Out:
# 'i'

# %%
#negative indexing from -1
myname[-1]
# Out:
# 'e'

# %%
#slicising
myname[0:4]
# Out:
# 'joji'

# %%
x = "hello python programming"
x[13:24]
# Out:
# 'programming'

# %%
x[-12:-1]
# Out:
# ' programmin'

# %%
x[6:12]
# Out:
# 'python'

# %%
x[-19:-12]
# Out:
# ' python'

# %%
#string operation
a = "hello, world!"
print(a.split(","))
# Out:
# ['hello', ' world!']

# %%
a = "hello, world!"
print(a.replace("h","J"))
# Out:
# Jello, world!

# %%
a = "hello, world!"
print(a.lower())
# Out:
# hello, world!

# %%
a = "hello, world!"
print(a.upper())
# Out:
# HELLO, WORLD!

# %%
a = "Hello"
b = "World"
c = a + " " + b
print(c)
# Out:
# Hello World

# %%
#string formattimg
age = 36
txt = "My name is John, I am {}"
print(txt.format(age))
# Out:
# My name is John, I am 36

# %%
age = 36
txt = f"My name is John, and I am {age} years old."
print(txt)
# Out:
# My name is John, and I am 36 years old.

# %%
str1 = "computer"
str2 = "engineering"
str3 = str1 + ' ' + str2
str3
# Out:
# 'computer engineering'

# %%
str4 = "python"
str5 = str4 * 3
str5
# Out:
# 'pythonpythonpython'

# %%
'y' in 'python'
'l' in 'programming'
# Out:
# False

# %%
mystring = "my name is joji george"
len(mystring)
# Out:
# 22

# %%
mystring.title()
# Out:
# 'My Name Is Joji George'

# %%
mystring.capitalize()
# Out:
# 'My name is joji george'

# %%
mystring.upper()
# Out:
# 'MY NAME IS JOJI GEORGE'
